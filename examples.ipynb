# %% [markdown]
# <p align="center">
#     <img src="https://user-images.githubusercontent.com/46355364/219180773-7c70fe5d-8597-43ce-8b11-96dee2afb98a.png" alt="Logo">
# </center>
# <p align="center">
#     <a href="https://www.buymeacoffee.com/jerbouma">
#         <img src="https://img.shields.io/badge/Buy%20Me%20A%20Coffee-Donate-brightgreen?logo=buymeacoffee" alt="Logo">
#     </a>
#     <a href="https://github.com/JerBouma/FinanceDatabase/issues">
#         <img src="https://img.shields.io/github/issues/jerbouma/financedatabase" alt="Logo">
#     </a>
#      <a href="https://github.com/JerBouma/FinanceDatabase/pulls">
#         <img src="https://img.shields.io/github/issues-pr/JerBouma/FinanceDatabase?color=yellow" alt="Logo">
#     </a>
#     <a href="https://pypi.org/project/financedatabase/">
#         <img src="https://img.shields.io/pypi/v/FinanceDatabase" alt="Logo">
#     </a>
#     <a href="https://pypi.org/project/financedatabase/">
#         <img src="https://img.shields.io/pypi/dm/FinanceDatabase" alt="Logo">
#     </a>
# </center>
#
# The **FinanceDatabase** serves the role of providing anyone with any type of financial product categorisation entirely for free. To be able to achieve this, the FinanceDatabase relies on involvement from the community to update, edit and remove tickers over time. This is made easy enough that anyone, even with a lack of coding experience can contribute because of the generation of JSON files that can be manually edited. I'd like to invite you to go to the **[Contributing Guidelines](https://github.com/JerBouma/FinanceDatabase/blob/main/CONTRIBUTING.md)** to understand how you can help. Thank you!
#
# As a private investor, the sheer amount of information that can be found on the internet is rather daunting. Trying to
# understand what type of companies or ETFs are available is incredibly challenging with there being millions of
# companies and derivatives available on the market. Sure, the most traded companies and ETFs can quickly be found
# simply because they are known to the public (for example, Microsoft, Tesla, S&P500 ETF or an All-World ETF). However,
# what else is out there is often unknown.
#
# **This database tries to solve that**. It features 300.000+ symbols containing Equities, ETFs, Funds, Indices,
# Currencies, Cryptocurrencies and Money Markets. It therefore allows you to obtain a broad overview of sectors,
# industries, types of investments and much more.
#
# The aim of this database is explicitly _not_ to provide up-to-date fundamentals or stock data as those can be obtained
# with ease (with the help of this database) by using [yfinance](https://github.com/ranaroussi/yfinance) or [FundamentalAnalysis](https://github.com/JerBouma/FundamentalAnalysis). Instead, it gives insights into the products
# that exist in each country, industry and sector and gives the most essential information about each product. With
# this information, you can analyse specific areas of the financial world and/or find a product that is hard to find.

# %% [markdown]
# ## Table of Contents
#
# 1. [Installation](#installation)
# 2. [Quick Start](#quickstart)
# 3. [Understanding the available options](#understanding-the-available-options)
# 4. [Collecting information from the database](#collecting-information-from-the-database)
#    1. [Equities](#equities)
#    2. [ETFs](#etfs)
#    3. [Funds](#funds)
#    4. [Indices](#indices)
#    5. [Currencies](#currencies)
#    6. [Cryptocurrencies](#cryptocurrencies)
#    7. [Money Markets](#moneymarkets)
# 5. [Searching the database in detail](#searching-the-database-in-detail)

# %% [markdown]
# # Installation
# The package `financedatabase` allows you to select specific json files as well as search through collected data with a specific query.
#
# You can install the package with the following steps:
# 1. `pip install financedatabase`
#     - Alternatively, download the 'Searcher' directory.
# 2. (within Python) `import financedatabase as fd`

# %%
import financedatabase as fd
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # Quickstart

# %% [markdown]
# Same methods apply to all other asset classes as well. Columns may vary.

# %%
# Initialize the Equities database
equities = fd.Equities()

# Obtain all countries from the database
equities_countries = equities.options('country')

# Obtain all sectors from the database
equities_sectors = equities.options('sector')

# Obtain all industries from a country from the database
equities_germany_industries = equities.options('industry', country='Germany')

# Obtain a selection from the database
equities_united_states = equities.select(country="United States")

# Obtain a detailed selection from the database
equities_usa_consumer_electronics = equities.select(country="United States", industry="Consumer Electronics")

# Search specific fields from the database
equities_uk_biotech = equities.search(country='United Kingdom', summary='biotech', exchange='LSE')

# %% [markdown]
# # Understanding the available options

# %% [markdown]
# Understanding which countries, sectors, industries and categories exist is important to be able to search the database properly. Not only to understand the focus a specific the country but also to understand which area holds the most data. This is a demonstration of the ```show_options``` function, a function crucial to querying data from the Database. The output of all functionalities is cut off in this README for illustration purposes.
#
# Let's start by acquiring the unique countries, sectors and industries of all equities in the database:

# %%
# Initialize the Equities database
equities = fd.Equities()

# %% [markdown]
# For countries, you will find the following list if you print `equities_countries`:
#
# `Afghanistan, Anguilla, Argentina, Australia, Austria, Azerbaijan, Bahamas, Bangladesh, Barbados, Belgium, Belize, Bermuda, Botswana, Brazil, British Virgin Islands, Cambodia, Canada, Cayman Islands, Chile, China, Colombia, Costa Rica, Cyprus, Czech Republic, Denmark, Dominican Republic, Egypt, Estonia, Falkland Islands, Finland, France, French Guiana, Gabon, Georgia, Germany, Ghana, Gibraltar, Greece, Greenland, ...`

# %%
# Obtain all countries from the database
equities.options('country')
# Out:
# array(['Anguilla', 'Argentina', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Barbados', 'Belgium', 'Belize', 'Bermuda', 'Brazil',
#        'British Virgin Islands', 'Cambodia', 'Canada', 'Cayman Islands',
#        'Chile', 'China', 'Colombia', 'Costa Rica', 'Cyprus',
#        'Czech Republic', 'Denmark', 'Dominican Republic', 'Egypt',
#        'Finland', 'France', 'Georgia', 'Germany', 'Ghana', 'Gibraltar',
#        'Greece', 'Guernsey', 'Hong Kong', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Japan',
#        'Jersey', 'Jordan', 'Kazakhstan', 'Lithuania', 'Luxembourg',
#        'Macau', 'Macedonia', 'Malaysia', 'Malta', 'Mauritius', 'Mexico',
#        'Monaco', 'Mongolia', 'Montenegro', 'Netherlands',
#        'Netherlands Antilles', 'New Zealand', 'Nigeria', 'Norway',
#        'Panama', 'Papua New Guinea', 'Peru', 'Philippines', 'Poland',
#        'Portugal', 'Romania', 'Russia', 'Singapore', 'South Africa',
#        'South Korea', 'Spain', 'Suriname', 'Sweden', 'Switzerland',
#        'Taiwan', 'Tanzania', 'Thailand', 'Turkey', 'United Arab Emirates',
#        'United Kingdom', 'United States', 'Uruguay'], dtype=object)

# %% [markdown]
# For sectors, you will find the following list if you print `equities_sectors`:
#
# `Basic Materials, Communication Services, Conglomerates, Consumer Cyclical, Consumer Defensive, Consumer Goods, Energy, Financial, Financial Services, Healthcare, Industrial Goods, Industrials, Real Estate, Services, Technology, Utilities`

# %%
# Obtain all sectors from the database
equities.options('sector')
# Out:
# array(['Basic Materials', 'Communication Services', 'Conglomerates',
#        'Consumer Cyclical', 'Consumer Defensive', 'Consumer Goods',
#        'Energy', 'Financial', 'Financial Services', 'Healthcare',
#        'Industrial Goods', 'Industrials', 'Real Estate', 'Services',
#        'Technology', 'Utilities'], dtype=object)

# %% [markdown]
# For industries, you will find the following list if you print `equities_industries`:
#
# `Advertising Agencies, Aerospace & Defense, Aerospace Defense - Major Diversified, Aerospace Defense Products & Services, Agricultural Chemicals, Agricultural Inputs, Air Delivery & Freight Services, Airlines, Airports & Air Services, Aluminum, Apparel Manufacturing, Apparel Retail, Apparel Stores, Asset Management, Auto & Truck Dealerships, Auto Dealerships, Auto Manufacturers, ...`

# %%
# Obtain all industries from the database
equities.options('industry')
# Out:
# array(['Advertising Agencies', 'Aerospace & Defense',
#        'Aerospace Defense Products & Services', 'Agricultural Inputs',
#        'Airlines', 'Airports & Air Services', 'Aluminum',
#        'Apparel Manufacturing', 'Apparel Retail', 'Asset Management',
#        'Auto & Truck Dealerships', 'Auto Manufacturers', 'Auto Parts',
#        'Banks - Diversified', 'Banks - Regional', 'Beverages - Brewers',
#        'Beverages - Non-Alcoholic', 'Beverages - Wineries & Distilleries',
#        'Biotechnology', 'Broadcasting', 'Broadcasting - TV',
#        'Building Materials', 'Building Products & Equipment',
#        'Business Equipment & Supplies', 'Business Services',
#        'Business Software & Services', 'Capital Markets', 'Chemicals',
#        'Cigarettes', 'Closed-End Fund - Equity', 'Coking Coal',
#        'Communication Equipment', 'Computer Hardware', 'Confectioners',
#        'Conglomerates', 'Consulting Services', 'Consumer Electronics',
#        'Copper', 'Credit Services', 'Department Stores',
#        'Diagnostics & Research', 'Discount Stores',
#        'Diversified Computer Systems', 'Diversified Electronics',
#        'Diversified Investments', 'Diversified Machinery',
#        'Diversified Utilities', 'Drug Manufacturers - General',
#        'Drug Manufacturers - Other',
#        'Drug Manufacturers - Specialty & Generic', 'Drugs - Generic',
#        'Education & Training Services', 'Electric Utilities',
#        'Electrical Equipment & Parts', 'Electronic Components',
#        'Electronic Gaming & Multimedia',
#        'Electronics & Computer Distribution',
#        'Engineering & Construction', 'Entertainment',
#        'Entertainment - Diversified',
#        'Farm & Heavy Construction Machinery', 'Farm Products',
#        'Financial Conglomerates', 'Financial Data & Stock Exchanges',
#        'Food - Major Diversified', 'Food Distribution',
#        'Footwear & Accessories', 'Furnishings, Fixtures & Appliances',
#        'Gambling', 'General Contractors', 'Gold', 'Grocery Stores',
#        'Health Information Services', 'Healthcare Plans',
#        'Home Improvement Retail', 'Household & Personal Products',
#        'Independent Oil & Gas', 'Industrial Distribution',
#        'Industrial Equipment Wholesale', 'Industrial Metals & Minerals',
#        'Information Technology Services', 'Infrastructure Operations',
#        'Insurance - Diversified', 'Insurance - Life',
#        'Insurance - Property & Casualty', 'Insurance - Reinsurance',
#        'Insurance - Specialty', 'Insurance Brokers',
#        'Integrated Freight & Logistics', 'Internet Content & Information',
#        'Internet Information Providers', 'Internet Retail',
#        'Internet Service Providers', 'Internet Software & Services',
#        'Leisure', 'Lodging', 'Long Distance Carriers',
#        'Lumber & Wood Production', 'Luxury Goods', 'Marine Shipping',
#        'Marketing Services', 'Medical Appliances & Equipment',
#        'Medical Care Facilities', 'Medical Devices',
#        'Medical Distribution', 'Medical Instruments & Supplies',
#        'Metal Fabrication', 'Mortgage Finance',
#        'Networking & Communication Devices', 'Nonmetallic Mineral Mining',
#        'Oil & Gas Drilling', 'Oil & Gas Drilling & Exploration',
#        'Oil & Gas E&P', 'Oil & Gas Equipment & Services',
#        'Oil & Gas Integrated', 'Oil & Gas Midstream',
#        'Oil & Gas Refining & Marketing',
#        'Other Industrial Metals & Mining',
#        'Other Precious Metals & Mining', 'Packaged Foods',
#        'Packaging & Containers', 'Paper & Paper Products',
#        'Personal Services', 'Pharmaceutical Retailers',
#        'Pollution & Treatment Controls', 'Processed & Packaged Goods',
#        'Publishing', 'REIT - Diversified', 'REIT - Healthcare Facilities',
#        'REIT - Hotel & Motel', 'REIT - Industrial', 'REIT - Mortgage',
#        'REIT - Office', 'REIT - Residential', 'REIT - Retail',
#        'REIT - Specialty', 'Railroads', 'Real Estate - Development',
#        'Real Estate - Diversified', 'Real Estate Services',
#        'Recreational Vehicles', 'Regional - Mid-Atlantic Banks',
#        'Rental & Leasing Services', 'Research Services',
#        'Residential Construction', 'Resorts & Casinos', 'Restaurants',
#        'Scientific & Technical Instruments',
#        'Security & Protection Services', 'Security Software & Services',
#        'Semiconductor Equipment & Materials', 'Semiconductors',
#        'Shell Companies', 'Shipping', 'Silver', 'Software - Application',
#        'Software - Infrastructure', 'Solar',
#        'Specialized Health Services', 'Specialty Business Services',
#        'Specialty Chemicals', 'Specialty Industrial Machinery',
#        'Specialty Retail', 'Specialty Retail, Other',
#        'Staffing & Employment Services',
#        'Staffing & Outsourcing Services', 'Steel', 'Telecom Services',
#        'Textile - Apparel Clothing', 'Textile Manufacturing',
#        'Thermal Coal', 'Tobacco', 'Tools & Accessories',
#        'Travel Services', 'Trucking', 'Uranium',
#        'Utilities - Diversified',
#        'Utilities - Independent Power Producers',
#        'Utilities - Regulated Electric', 'Utilities - Regulated Gas',
#        'Utilities - Regulated Water', 'Utilities - Renewable',
#        'Waste Management', 'Wireless Communications'], dtype=object)

# %% [markdown]
# When you wish to get country, sector or industry specific lists, you can use the related `country`, `sector` and `industry` tags as also found in the help window with `help(equities.options)`

# %%
help(equities.options)
# Out:
# Help on method options in module financedatabase.equities:
#
# options(selection: str, country: str = '', sector: str = '', industry: str = '') -> pandas.core.series.Series method of financedatabase.equities.Equities instance
#     Description
#     ----
#     Returns all options for the selection provided.
#
#     Input
#     ----
#     selection (string)
#         The selection you want to see the options for. Can be:
#         - country
#         - sector
#         - industry
#     country (string, default is None)
#         If filled, gives all data for a specific country.
#     sector (string, default is None)
#         If filled, gives all data for a specific sector.
#     industry (string, default is None)
#         If filled, gives all data for a specific industry.
#     Output
#     ----
#     options (pd.Series)
#         Returns a series with all options for the selection provided.

# %% [markdown]
# For example, if I wish to know all available industries within the sector "Basic Materials" in the country United States I can use

# %%
# Obtain a filtered selection of available industries
equities.options(selection='industry', country="United States", sector="Basic Materials")
# Out:
# array(['Agricultural Inputs', 'Aluminum', 'Building Materials',
#        'Chemicals', 'Coking Coal', 'Copper', 'Gold',
#        'Independent Oil & Gas', 'Industrial Metals & Minerals',
#        'Lumber & Wood Production', 'Nonmetallic Mineral Mining',
#        'Oil & Gas Drilling & Exploration',
#        'Oil & Gas Equipment & Services',
#        'Other Industrial Metals & Mining',
#        'Other Precious Metals & Mining', 'Paper & Paper Products',
#        'Silver', 'Specialty Chemicals', 'Steel'], dtype=object)

# %% [markdown]
# This also extends further if you are looking into a different category. For example, find all available currencies by using

# %%
# Initialize the Currencies database
currencies = fd.Currencies()

# Obtain all available currencies
currencies.options()
# Out:
# array(['AED', 'AFN', 'ALL', 'AMD', 'ANG', 'AOA', 'ARS', 'AUD', 'AWG',
#        'AZN', 'BAM', 'BBD', 'BDT', 'BGN', 'BHD', 'BIF', 'BMD', 'BND',
#        'BOB', 'BRL', 'BRX', 'BSD', 'BTN', 'BWP', 'BYN', 'BZD', 'CAD',
#        'CAX', 'CDF', 'CHF', 'CLF', 'CLP', 'CNH', 'CNY', 'COP', 'CRC',
#        'CUC', 'CUP', 'CVE', 'CZK', 'CZX', 'DJF', 'DKK', 'DKX', 'DOP',
#        'DZD', 'EGP', 'ERN', 'ETB', 'EUR', 'FJD', 'FKP', 'GBP', 'GEL',
#        'GHS', 'GIP', 'GMD', 'GNF', 'GTQ', 'GYD', 'HKD', 'HNL', 'HRK',
#        'HRX', 'HTG', 'HUF', 'HUX', 'IDR', 'ILS', 'INR', 'IQD', 'IRR',
#        'ISK', 'ISX', 'JMD', 'JOD', 'JPY', 'KES', 'KGS', 'KHR', 'KMF',
#        'KPW', 'KRW', 'KWD', 'KYD', 'KZT', 'LAK', 'LBP', 'LKR', 'LRD',
#        'LSL', 'LYD', 'MAD', 'MDL', 'MGA', 'MKD', 'MMK', 'MNT', 'MOP',
#        'MRU', 'MUR', 'MVR', 'MWK', 'MXN', 'MXV', 'MXX', 'MYR', 'MYX',
#        'MZN', 'NAD', 'NGN', 'NIO', 'NOK', 'NPR', 'NZD', 'OMR', 'PAB',
#        'PEN', 'PGK', 'PHP', 'PKR', 'PLN', 'PLX', 'PYG', 'QAR', 'RON',
#        'RSD', 'RUB', 'RUX', 'RWF', 'SAR', 'SBD', 'SCR', 'SDG', 'SEK',
#        'SGD', 'SHP', 'SLL', 'SOS', 'SRD', 'STN', 'SVC', 'SYP', 'SZL',
#        'THB', 'THX', 'TJS', 'TMT', 'TND', 'TOP', 'TRY', 'TTD', 'TWD',
#        'TZS', 'UAH', 'UGX', 'USD', 'UYU', 'UZS', 'VES', 'VND', 'VUV',
#        'WST', 'XAF', 'XCD', 'XCU', 'XDR', 'XOF', 'XPF', 'YER', 'ZAC',
#        'ZAR', 'ZMW'], dtype=object)

# %% [markdown]
# But also when it comes to `etfs` with

# %%
# Initialize the ETFs database
etfs = fd.ETFs()

# Obtain all availables categories
etfs.options(selection="category")
# Out:
# array(['Allocation--15% to 30% Equity', 'Allocation--30% to 50% Equity',
#        'Allocation--50% to 70% Equity', 'Allocation--70% to 85% Equity',
#        'Allocation--85%+ Equity', 'Bank Loan', 'Bear Market',
#        'China Region', 'Commodities Broad Basket', 'Communications',
#        'Consumer Cyclical', 'Consumer Defensive', 'Convertibles',
#        'Corporate Bond', 'Diversified Emerging Mkts',
#        'Diversified Pacific/Asia', 'Emerging Markets Bond',
#        'Emerging-Markets Local-Currency Bond',
#        'Energy Limited Partnership', 'Equity Energy',
#        'Equity Precious Metals', 'Europe Stock', 'Financial',
#        'Foreign Large Blend', 'Foreign Large Growth',
#        'Foreign Large Value', 'Foreign Small/Mid Blend',
#        'Foreign Small/Mid Growth', 'Foreign Small/Mid Value',
#        'Global Real Estate', 'Health', 'High Yield Bond',
#        'High Yield Muni', 'India Equity', 'Industrials',
#        'Inflation-Protected Bond', 'Infrastructure',
#        'Intermediate Government', 'Intermediate-Term Bond', 'Japan Stock',
#        'Large Blend', 'Large Growth', 'Large Value',
#        'Latin America Stock', 'Long Government', 'Long-Short Credit',
#        'Long-Short Equity', 'Long-Term Bond', 'Managed Futures',
#        'Market Neutral', 'Mid-Cap Blend', 'Mid-Cap Growth',
#        'Mid-Cap Value', 'Miscellaneous Region', 'Miscellaneous Sector',
#        'Multialternative', 'Multicurrency', 'Multisector Bond',
#        'Muni California Long', 'Muni Minnesota', 'Muni National Interm',
#        'Muni National Long', 'Muni National Short',
#        'Muni New York Intermediate', 'Natural Resources',
#        'Nontraditional Bond', 'Option Writing',
#        'Pacific/Asia ex-Japan Stk', 'Preferred Stock', 'Real Estate',
#        'Short Government', 'Short-Term Bond', 'Single Currency',
#        'Small Blend', 'Small Growth', 'Small Value',
#        'Tactical Allocation', 'Technology',
#        'Trading--Inverse Commodities', 'Trading--Inverse Debt',
#        'Trading--Inverse Equity', 'Trading--Leveraged Commodities',
#        'Trading--Leveraged Debt', 'Trading--Leveraged Equity',
#        'Trading--Miscellaneous', 'Ultrashort Bond', 'Utilities',
#        'Volatility', 'World Allocation', 'World Bond', 'World Stock'],
#       dtype=object)

# %% [markdown]
# # Collecting information from the database

# %% [markdown]
# ## Equities

# %% [markdown]
# If you wish to collect data from all equities you can use the following:

# %%
equities = fd.Equities()

equities.select()
# Out:
#                              short_name  \
# symbol
# NaN                                 NaN
# A            Agilent Technologies, Inc.
# AA                    Alcoa Corporation
# AAALF                    AAREAL BANK AG
# AAALY                    AAREAL BANK AG
# ...                                 ...
# ZYXI                        Zynex, Inc.
# ZZHGF   ZHONGAN ONLINE P & C INS CO LTD
# ZZHGY   ZHONGAN ONLINE P & C INS CO LTD
# ZZLL    ZZLL INFORMATION TECHNOLOGY INC
# ZZZOF            ZINC ONE RESOURCES INC
#
#                                        long_name  \
# symbol
# NaN                                          NaN
# A                     Agilent Technologies, Inc.
# AA                             Alcoa Corporation
# AAALF                             Aareal Bank AG
# AAALY                             Aareal Bank AG
# ...                                          ...
# ZYXI                                 Zynex, Inc.
# ZZHGF   ZhongAn Online P & C Insurance Co., Ltd.
# ZZHGY   ZhongAn Online P & C Insurance Co., Ltd.
# ZZLL           ZZLL Information Technology, Inc.
# ZZZOF                    Zinc One Resources Inc.
#
#                                                   summary currency  \
# symbol
# NaN                                                   NaN      NaN
# A       Agilent Technologies, Inc. provides applicatio...      USD
# AA      Alcoa Corporation, together with its subsidiar...      USD
# AAALF   Aareal Bank AG, together with its subsidiaries...      USD
# AAALY                                                 NaN      USD
# ...                                                   ...      ...
# ZYXI    Zynex, Inc., through its subsidiaries, designs...      USD
# ZZHGF   ZhongAn Online P & C Insurance Co., Ltd., an i...      USD
# ZZHGY                                                 NaN      USD
# ZZLL    ZZLL Information Technology, Inc., through its...      USD
# ZZZOF   Zinc One Resources Inc. engages in the acquisi...      USD
#
#                         sector                          industry exchange  \
# symbol
# NaN                        NaN                               NaN      NaN
# A                   Healthcare            Diagnostics & Research      NYQ
# AA             Basic Materials                          Aluminum      NYQ
# AAALF                      NaN                               NaN      PNK
# AAALY                      NaN                               NaN      PNK
# ...                        ...                               ...      ...
# ZYXI                Healthcare                   Medical Devices      NCM
# ZZHGF       Financial Services   Insurance - Property & Casualty      PNK
# ZZHGY                      NaN                               NaN      PNK
# ZZLL    Communication Services    Internet Content & Information      PNK
# ZZZOF          Basic Materials  Other Industrial Metals & Mining      PNK
#
#            market        country state         city     zipcode  \
# symbol
# NaN           NaN            NaN   NaN          NaN         NaN
# A       us_market  United States    CA  Santa Clara       95051
# AA      us_market  United States    PA   Pittsburgh  15212-5858
# AAALF   us_market        Germany   NaN    Wiesbaden       65189
# AAALY   us_market            NaN   NaN          NaN         NaN
# ...           ...            ...   ...          ...         ...
# ZYXI    us_market  United States    CO    Englewood       80112
# ZZHGF   us_market          China   NaN     Shanghai         NaN
# ZZHGY   us_market            NaN   NaN          NaN         NaN
# ZZLL    us_market      Hong Kong   NaN  North Point         NaN
# ZZZOF   us_market         Canada    BC    Vancouver     V6E 4H1
#
#                            website market_cap
# symbol
# NaN                            NaN        NaN
# A           http://www.agilent.com  Large Cap
# AA            http://www.alcoa.com    Mid Cap
# AAALF   http://www.aareal-bank.com  Small Cap
# AAALY                          NaN        NaN
# ...                            ...        ...
# ZYXI          http://www.zynex.com  Small Cap
# ZZHGF       http://www.zhongan.com    Mid Cap
# ZZHGY                          NaN        NaN
# ZZLL        http://www.zzlliti.com   Nano Cap
# ZZZOF       http://www.zincone.com  Micro Cap
#
# [20063 rows x 14 columns]

# %% [markdown]
# This returns approximately 20.000 different equities. Note that by default, only the American exchanges are selected. These are symbols like `TSLA` (Tesla) and `MSFT` (Microsoft) that tend to be recognized by a majority of data providers and therefore is the default. To disable this, you can set the `exclude_exchanges` argument to `False` which then results in approximately 155.000 different symbols. Find a more elaborate explanation with `help(equities.select)`:

# %%
help(equities.select)
# Out:
# Help on method select in module financedatabase.equities:
#
# select(country: str = '', sector: str = '', industry: str = '', exclude_exchanges: bool = True, capitalize: bool = True) -> pandas.core.frame.DataFrame method of financedatabase.equities.Equities instance
#     Description
#     ----
#     Returns all equities when no input is given and has the option to give
#     a specific set of symbols for the country, sector and/or industry provided.
#
#     The data depends on the combination of inputs. For example Country + Sector
#     gives all symbols for a specific sector in a specific country.
#
#     Input
#     ----
#     country (string, default is None)
#         If filled, gives all data for a specific country.
#     sector (string, default is None)
#         If filled, gives all data for a specific sector.
#     industry (string, default is None)
#         If filled, gives all data for a specific industry.
#     exclude_exchanges (boolean, default is True):
#         Whether you want to exclude exchanges from the search. If False,
#         you will receive multiple times the product from different exchanges.
#     capitalize (boolean, default is True):
#         Whether country, sector and industry needs to be capitalized. By default
#         the values always are capitalized as that is also how it is represented
#         in the csv files.
#     base_url (string, default is GitHub location)
#         The possibility to enter your own location if desired.
#     use_local_location (string, default False)
#         The possibility to select a local location (i.e. based on Windows path)
#
#     Output
#     ----
#     equities_df (pd.DataFrame)
#         Returns a dictionary with a selection or all data based on the input.

# %% [markdown]
# As an example, in [Understanding the available options](#understanding-the-available-options),we've used `equities.options(selection='industry', country="United States", sector="Basic Materials")` which allowed us to look at a specific industry in the United States. So with this information in hand, I can now query the industry `Aluminum` as follows:

# %%
equities.select(country="United States", sector="Basic Materials", industry="Aluminum")
# Out:
#                          short_name                             long_name  \
# symbol
# AA                Alcoa Corporation                     Alcoa Corporation
# CENX       Century Aluminum Company              Century Aluminum Company
# KALU    Kaiser Aluminum Corporation           Kaiser Aluminum Corporation
# NORNQ        NORANDA ALUM HLDG CORP  Noranda Aluminum Holding Corporation
# ORMTQ                    ORMET CORP                     Ormet Corporation
#
#                                                   summary currency  \
# symbol
# AA      Alcoa Corporation, together with its subsidiar...      USD
# CENX    Century Aluminum Company, together with its su...      USD
# KALU    Kaiser Aluminum Corporation manufactures and s...      USD
# NORNQ   Noranda Aluminum Holding Corporation produces ...      USD
# ORMTQ   Ormet Corporation engages in the production an...      USD
#
#                  sector  industry exchange     market        country state  \
# symbol
# AA      Basic Materials  Aluminum      NYQ  us_market  United States    PA
# CENX    Basic Materials  Aluminum      NMS  us_market  United States    IL
# KALU    Basic Materials  Aluminum      NMS  us_market  United States    CA
# NORNQ   Basic Materials  Aluminum      PNK  us_market  United States    TN
# ORMTQ   Basic Materials  Aluminum      PNK  us_market  United States    OH
#
#                   city     zipcode                        website market_cap
# symbol
# AA          Pittsburgh  15212-5858           http://www.alcoa.com    Mid Cap
# CENX           Chicago       60606     http://centuryaluminum.com  Small Cap
# KALU    Foothill Ranch  92610-2831  http://www.kaiseraluminum.com    Mid Cap
# NORNQ         Franklin       37067                            NaN   Nano Cap
# ORMTQ         Hannibal       43931                            NaN   Nano Cap

# %% [markdown]
# ## ETFs

# %% [markdown]
# If you wish to collect data from all etfs you can use the following:

# %%
etfs = fd.ETFs()

etfs.select()
# Out:
#                              short_name  \
# symbol
# AAA     Listed Funds Trust AAF First Pr
# AAAU    Goldman Sachs Physical Gold ETF
# AADR        AdvisorShares Dorsey Wright
# AAXJ    iShares MSCI All Country Asia e
# ABCS    Guggenheim ABC High Dividend ET
# ...                                 ...
# ^VTWG                VANGUARD SCOTTSDAL
# ^VTWO                VANGUARD SCOTTSDAL
# ^VTWV                VANGUARD SCOTTSDAL
# ^VWOB                VANGUARD WHITEHALL
# ^VYMI                VANGUARD WHITEHALL
#
#                                          long_name currency  \
# symbol
# AAA                AAF First Priority CLO Bond ETF      USD
# AAAU               Goldman Sachs Physical Gold ETF      USD
# AADR           AdvisorShares Dorsey Wright ADR ETF      USD
# AAXJ    iShares MSCI All Country Asia ex Japan ETF      USD
# ABCS                                           NaN      NaN
# ...                                            ...      ...
# ^VTWG                                          NaN      USD
# ^VTWO                                          NaN      USD
# ^VTWV                                          NaN      USD
# ^VWOB                                          NaN      USD
# ^VYMI                                          NaN      USD
#
#                                                   summary  \
# symbol
# AAA     The investment seeks capital preservation and ...
# AAAU    The investment seeks to provide investors with...
# AADR                                                  NaN
# AAXJ    The investment seeks to track the investment r...
# ABCS                                                  NaN
# ...                                                   ...
# ^VTWG                                                 NaN
# ^VTWO                                                 NaN
# ^VTWV                                                 NaN
# ^VWOB                                                 NaN
# ^VYMI                                                 NaN
#
#                          category                    family exchange  \
# symbol
# AAA                           NaN  Alternative Access Funds      PCX
# AAAU                          NaN  Exchange Traded Concepts      PCX
# AADR                          NaN                       NaN      NMS
# AAXJ    Pacific/Asia ex-Japan Stk                   iShares      NMS
# ABCS                          NaN                       NaN      PCX
# ...                           ...                       ...      ...
# ^VTWG                         NaN                       NaN      NIM
# ^VTWO                         NaN                       NaN      NIM
# ^VTWV                         NaN                       NaN      NIM
# ^VWOB                         NaN                       NaN      NIM
# ^VYMI                         NaN                       NaN      NIM
#
#            market  total_assets
# symbol
# AAA     us_market  1.001962e+07
# AAAU    us_market  3.317956e+08
# AADR    us_market           NaN
# AAXJ    us_market  6.588896e+09
# ABCS    us_market           NaN
# ...           ...           ...
# ^VTWG   us_market           NaN
# ^VTWO   us_market           NaN
# ^VTWV   us_market           NaN
# ^VWOB   us_market           NaN
# ^VYMI   us_market           NaN
#
# [2841 rows x 9 columns]

# %% [markdown]
# This returns approximately 2.500 different ETFs. Note that by default, only the American exchanges are selected. These are symbols like `SPY` (SPDR S&P 500 ETF Trust) and `VTI` (Vanguard Total Stock Market Index Fund ETF) that tend to be recognized by a majority of data providers and therefore is the default. To disable this, you can set the `exclude_exchanges` argument to `False` which then results in approximately 35.000 different symbols. Find a more elaborate explanation with `help(etfs.select)`:

# %%
help(etfs.select)
# Out:
# Help on method select in module financedatabase.etfs:
#
# select(category: str = '', family: str = '', exclude_exchanges: bool = True, capitalize: bool = True) -> pandas.core.frame.DataFrame method of financedatabase.etfs.ETFs instance
#     Description
#     ----
#     Returns all etfs when no input is given and has the option to give
#     a specific set of symbols for the category and/or family provided.
#
#     The data depends on the combination of inputs. For example Category + Family
#     gives all symbols for a specific category for a specific family.
#
#     Input
#     ----
#     category (string, default is None)
#         If filled, gives all data for a specific category.
#     family (string, default is None)
#         If filled, gives all data for a specific family.
#     exclude_exchanges (boolean, default is True):
#         Whether you want to exclude exchanges from the search. If False,
#         you will receive multiple times the product from different exchanges.
#     capitalize (boolean, default is True):
#         Whether country, sector and industry needs to be capitalized. By default
#         the values always are capitalized as that is also how it is represented
#         in the csv files.
#     base_url (string, default is GitHub location)
#         The possibility to enter your own location if desired.
#     use_local_location (string, default False)
#         The possibility to select a local location (i.e. based on Windows path)
#
#     Output
#     ----
#     etfs_df (pd.DataFrame)
#         Returns a dictionary with a selection or all data based on the input.

# %% [markdown]
# With this information in hand, and having seen the available options within [Understanding the available options](#understanding-the-available-options), we can specify the selection as follows:

# %%
etfs.select(category="Large Value")
# Out:
#                              short_name  \
# symbol
# ABEQ         Absolute Core Strategy ETF
# AFLG    First Trust Active Factor Large
# BUFF    Innovator Laddered Fund of S&P
# CAPE             iPath Shiller CAPE ETN
# CDL     VictoryShares US Large Cap High
# ...                                 ...
# VSMV    VictoryShares US Multi-Factor M
# VTV                  Vanguard Value ETF
# VYM     Vanguard High Dividend Yield ET
# WBIF        WBI BullBear Value 3000 ETF
# WBIG        WBI BullBear Yield 3000 ETF
#
#                                                 long_name currency  \
# symbol
# ABEQ                           Absolute Core Strategy ETF      USD
# AFLG              First Trust Active Factor Large Cap ETF      USD
# BUFF    Innovator Laddered Fund of S&P 500 Power Buffe...      USD
# CAPE                      Barclays ETN+ Shiller Capet ETN      USD
# CDL     VictoryShares US Large Cap High Div Volatility...      USD
# ...                                                   ...      ...
# VSMV    VictoryShares US Multi-Factor Minimum Volatili...      USD
# VTV                  Vanguard Value Index Fund ETF Shares      USD
# VYM     Vanguard High Dividend Yield Index Fund ETF Sh...      USD
# WBIF                          WBI BullBear Value 3000 ETF      USD
# WBIG                          WBI BullBear Yield 3000 ETF      USD
#
#                                                   summary     category  \
# symbol
# ABEQ    The investment seeks positive absolute returns...  Large Value
# AFLG    The investment seeks to provide capital apprec...  Large Value
# BUFF    The investment seeks investment results that g...  Large Value
# CAPE    The investment seeks to replicate, net of expe...  Large Value
# CDL     The investment seeks to provide investment res...  Large Value
# ...                                                   ...          ...
# VSMV    The investment seeks to provide investment res...  Large Value
# VTV     The investment seeks to track the performance ...  Large Value
# VYM     The investment seeks to track the performance ...  Large Value
# WBIF    The investment seeks long-term capital appreci...  Large Value
# WBIG    The investment seeks long-term capital appreci...  Large Value
#
#                                family exchange     market  total_assets
# symbol
# ABEQ     Absolute Investment Advisers      PCX  us_market  4.793857e+07
# AFLG                      First Trust      PCX  us_market  7.463054e+06
# BUFF                   Innovator ETFs      BTS  us_market  4.508586e+07
# CAPE    Milleis Investissements Funds      PCX  us_market  3.411541e+08
# CDL                   Victory Capital      NMS  us_market  2.103810e+08
# ...                               ...      ...        ...           ...
# VSMV                  Victory Capital      NGM  us_market  1.526884e+08
# VTV                          Vanguard      PCX  us_market  1.141915e+11
# VYM                          Vanguard      PCX  us_market  4.610147e+10
# WBIF                  WBI Investments      PCX  us_market  4.623108e+07
# WBIG                  WBI Investments      PCX  us_market  4.483739e+07
#
# [80 rows x 9 columns]

# %% [markdown]
# ## Funds

# %% [markdown]
# If you wish to collect data from all funds you can use the following:

# %%
funds = fd.Funds()

funds.select()
# Out:
#                               short_name  \
# symbol
# AAAAX    DWS RREEF Real Assets Fund - Cl
# AAACX         A3 Alternative Credit Fund
# AAAEX    AllianzGI Health Sciences Fund
# AAAFX                                NaN
# AAAGX    Thrivent Large Cap Growth Fund
# ...                                  ...
# ZVNBX    Zevenbergen Growth Fund - Inves
# ZVNIX    Zevenbergen Growth Fund - Insti
# ZVZZCNX  Nasdaq NextShares Test Instrume
# ZZZAX    Test Demand Deposit Account - T
# ZZZZIX   Nasdaq Test - AIP Managed Futur
#
#                                                  long_name currency  \
# symbol
# AAAAX                 DWS RREEF Real Assets Fund - Class A      USD
# AAACX                           A3 Alternative Credit Fund      USD
# AAAEX        Virtus AllianzGI Health Sciences Fund Class P      USD
# AAAFX    American Century One Choice Blend+ 2015 Portfo...      USD
# AAAGX               Thrivent Large Cap Growth Fund Class A      USD
# ...                                                    ...      ...
# ZVNBX               Zevenbergen Growth Fund Investor Class      USD
# ZVNIX          Zevenbergen Growth Fund Institutional Class      USD
# ZVZZCNX                                                NaN      USD
# ZZZAX                                                  NaN      USD
# ZZZZIX                                                 NaN      USD
#
#                                                    summary      manager_name  \
# symbol
# AAAAX    The investment seeks total return in excess of...    John  Vojticek
# AAACX                                                  NaN               NaN
# AAAEX    The investment seeks long-term capital appreci...     Peter  Pirsch
# AAAFX    The investment seeks the highest total return ...   Scott A. Wilson
# AAAGX    The investment seeks long-term capital appreci...    Lauri  Brunner
# ...                                                    ...               ...
# ZVNBX    The investment seeks long-term capital appreci...  Joseph  Dennison
# ZVNIX    The investment seeks long-term capital appreci...  Joseph  Dennison
# ZVZZCNX                                                NaN               NaN
# ZZZAX                                                  NaN               NaN
# ZZZZIX                                                 NaN               NaN
#
#                                                manager_bio          category  \
# symbol
# AAAAX    Co-Head of Liquid Real Assets / Chief Investme...  World Allocation
# AAACX                                                  NaN               NaN
# AAAEX    Mr. Pirsch is a senior portfolio manager, a se...            Health
# AAAFX    Mr. Wilson, Vice President and Portfolio Manag...  Target-Date 2015
# AAAGX    Ms. Brunner has been with Thrivent Financial s...      Large Growth
# ...                                                    ...               ...
# ZVNBX    Mr. Dennison joined ZCI in 2011.Â Â  In his cu...      Large Growth
# ZVNIX    Mr. Dennison joined ZCI in 2011.Â Â  In his cu...      Large Growth
# ZVZZCNX                                                NaN               NaN
# ZZZAX                                                  NaN               NaN
# ZZZZIX                                                 NaN               NaN
#
#                                   family exchange     market  total_assets
# symbol
# AAAAX                                DWS      NAS  us_market  1.128764e+09
# AAACX                                NaN      NAS  us_market           NaN
# AAAEX                             Virtus      NAS  us_market  1.871478e+08
# AAAFX       American Century Investments      NAS  us_market  2.556200e+04
# AAAGX                     Thrivent Funds      NAS  us_market  1.985473e+09
# ...                                  ...      ...        ...           ...
# ZVNBX    Zevenbergen Capital Investments      NAS  us_market  1.230049e+08
# ZVNIX    Zevenbergen Capital Investments      NAS  us_market  1.230049e+08
# ZVZZCNX                              NaN      NAS  us_market           NaN
# ZZZAX                                NaN      NAS  us_market           NaN
# ZZZZIX                               NaN      NAS  us_market           NaN
#
# [31440 rows x 11 columns]

# %% [markdown]
# This returns approximately 30.000 different Funds. Note that by default, only the American exchanges are selected. These are symbols that tend to be recognized by a majority of data providers and therefore is the default. To disable this, you can set the `exclude_exchanges` argument to `False` which then results in approximately 55.000 different symbols. Find a more elaborate explanation with `help(funds.select)`:

# %%
help(funds.select)
# Out:
# Help on method select in module financedatabase.funds:
#
# select(category: str = '', family: str = '', exclude_exchanges: bool = True, capitalize: bool = True) -> pandas.core.frame.DataFrame method of financedatabase.funds.Funds instance
#     Description
#     ----
#     Returns all funds when no input is given and has the option to give
#     a specific set of symbols for the category and/or family provided.
#
#     The data depends on the combination of inputs. For example Category + Family
#     gives all symbols for a specific category for a specific family.
#
#     Input
#     ----
#     category (string, default is None)
#         If filled, gives all data for a specific category.
#     family (string, default is None)
#         If filled, gives all data for a specific family.
#     exclude_exchanges (boolean, default is True):
#         Whether you want to exclude exchanges from the search. If False,
#         you will receive multiple times the product from different exchanges.
#     capitalize (boolean, default is True):
#         Whether country, sector and industry needs to be capitalized. By default
#         the values always are capitalized as that is also how it is represented
#         in the csv files.
#     base_url (string, default is GitHub location)
#         The possibility to enter your own location if desired.
#     use_local_location (string, default False)
#         The possibility to select a local location (i.e. based on Windows path)
#
#     Output
#     ----
#     funds_df (pd.DataFrame)
#         Returns a dictionary with a selection or all data based on the input.

# %% [markdown]
# With this information in hand, and having seen the available options within [Understanding the available options](#understanding-the-available-options), we can specify the selection as follows:

# %%
funds.select(category="Bear Market")
# Out:
#                              short_name  \
# symbol
# BRPIX       Bear ProFund Investor Class
# CPCRX   Comstock Capital Value Fund  Cl
# RYARX   Rydex Series Fds, Inverse S&P 5
# SOPIX   Short NASDAQ-100 ProFund Invest
#
#                                             long_name currency  \
# symbol
# BRPIX               ProFunds Bear Fund Investor Class      USD
# CPCRX             Comstock Capital Value Fund Class I      USD
# RYARX     Rydex Inverse S&P 500 Strategy Fund Class A      USD
# SOPIX   ProFunds Short NASDAQ-100 Fund Investor Class      USD
#
#                                                   summary      manager_name  \
# symbol
# BRPIX   The investment seeks daily investment results,...   Michael  Neches
# CPCRX   The investment seeks to maximize total return,...  Dennis J. DeCore
# RYARX   The investment seeks to provide investment res...    Ryan A. Harder
# SOPIX   The investment seeks daily investment results,...   Michael  Neches
#
#                                               manager_bio     category  \
# symbol
# BRPIX   Michael Neches joined ProShare Advisors in 200...  Bear Market
# CPCRX   Mr. DeCore has been a portfolio manager with G...  Bear Market
# RYARX   Ryan A. Harder, CFA, Portfolio Manager of Secu...  Bear Market
# SOPIX   Michael Neches joined ProShare Advisors in 200...  Bear Market
#
#              family exchange     market  total_assets
# symbol
# BRPIX      ProFunds      NAS  us_market    12616494.0
# CPCRX       Gabelli      NAS  us_market     3851067.0
# RYARX   Rydex Funds      NAS  us_market    62379188.0
# SOPIX      ProFunds      NAS  us_market     2379065.0

# %% [markdown]
# ## Indices

# %% [markdown]
# If you wish to collect data from all indices you can use the following:

# %%
indices = fd.Indices()

indices.select()
# Out:
#                                                short_name currency     market  \
# GBKX                         KBW Nasdaq Global Bank Index      NaN  us_market
# GBKXN       KBW Nasdaq Global Bank Net Total Return Index      NaN  us_market
# GBKXT           KBW Nasdaq Global Bank Total Return Index      NaN  us_market
# ^A1BSC                    Dow Jones Americas Basic Materi      USD  us_market
# ^A1CYC                    Dow Jones Americas Consumer Ser      USD  us_market
# ...                                                   ...      ...        ...
# ^ZSL-EU                   ProShares UltraShort Silver (Es      USD  us_market
# ^ZSL-IV                   ProShares UltraShort Silver (In      USD  us_market
# ^ZSL-NV                   ProShares UltraShort Silver (Ne      USD  us_market
# ^ZSL-TC                   ProShares UltraShort Silver (To      USD  us_market
# ^ZVZZT-624                          ZVZZT.624 Test Symbol      USD  us_market
#
#            exchange exchange timezone
# GBKX            NIM               EDT
# GBKXN           NIM               EDT
# GBKXT           NIM               EDT
# ^A1BSC          DJI               EDT
# ^A1CYC          DJI               EDT
# ...             ...               ...
# ^ZSL-EU         ASE               EDT
# ^ZSL-IV         ASE               EDT
# ^ZSL-NV         ASE               EDT
# ^ZSL-TC         ASE               EDT
# ^ZVZZT-624      NYS               EDT
#
# [62140 rows x 5 columns]

# %% [markdown]
# This returns approximately 60.000 different indices. Note that by default, only the American exchanges are selected. These are symbols like `^GSPC` (S&P 500) that tend to be recognized by a majority of data providers and therefore is the default. To disable this, you can set the `exclude_exchanges` argument to `False` which then results in approximately 90.000 different symbols. Find a more elaborate explanation with `help(indices.select)`:

# %%
help(indices.select)
# Out:
# Help on method select in module financedatabase.indices:
#
# select(currency: str = '', capitalize: bool = True, exclude_exchanges: bool = True) -> pandas.core.frame.DataFrame method of financedatabase.indices.Indices instance
#     Description
#     ----
#     Returns all indices when no input is given and has the option to give
#     a specific combination of indices based on the currency defined.
#
#     Input
#     ----
#     currency (string, default is None)
#         If filled, gives all data for a specific currency.
#     capitalize (boolean, default is True):
#         Whether the currency needs to be capitalized. By default the values
#         always are capitalized as that is also how it is represented in the csv files.
#     exclude_exchanges (boolean, default is True):
#         Whether you want to exclude exchanges from the search. If False,
#         you will receive multiple times the product from different exchanges.
#     base_url (string, default is GitHub location)
#         The possibility to enter your own location if desired.
#     use_local_location (string, default False)
#         The possibility to select a local location (i.e. based on Windows path)
#
#     Output
#     ----
#     indices_df (pd.DataFrame)
#         Returns a dictionary with a selection or all data based on the input.

# %% [markdown]
# ## Currencies

# %% [markdown]
# If you wish to collect data from all currencies you can use the following:

# %%
currencies = fd.Currencies()

currencies.select()
# Out:
#          short_name currency exchange      market
# symbol
# AED=X       USD/AED      AED      CCY  ccy_market
# AEDAUD=X    AED/AUD      AUD      CCY  ccy_market
# AEDBRX=X    AED/BRX      NaN      CCY  ccy_market
# AEDCAD=X    AED/CAD      CAD      CCY  ccy_market
# AEDCHF=X    AED/CHF      CHF      CCY  ccy_market
# ...             ...      ...      ...         ...
# ZMWEUR=X    ZMW/EUR      EUR      CCY  ccy_market
# ZMWGBP=X    ZMW/GBP      GBP      CCY  ccy_market
# ZMWJPY=X    ZMW/JPY      JPY      CCY  ccy_market
# ZMWUSD=X    ZMW/USD      USD      CCY  ccy_market
# ZMWZAR=X    ZMW/ZAR      NaN      CCY  ccy_market
#
# [2590 rows x 4 columns]

# %% [markdown]
# This returns approximately 2.500 different currencies. Find a more elaborate explanation with `help(currencies.select)`:

# %%
# Help Window
help(currencies.select)
# Out:
# Help on method select in module financedatabase.currencies:
#
# select(currency: str = '', capitalize: bool = True) -> pandas.core.frame.DataFrame method of financedatabase.currencies.Currencies instance
#     Description
#     ----
#     Returns all currencies when no input is given and has the option to give
#     a specific combination of currencies based on the currency defined.
#
#     Input
#     ----
#     currency (string, default is None)
#         If filled, gives all data for a specific currency.
#     capitalize (boolean, default is True):
#         Whether the currency needs to be capitalized. By default the values
#         always are capitalized as that is also how it is represented in the csv files.
#     base_url (string, default is GitHub location)
#         The possibility to enter your own location if desired.
#     use_local_location (string, default False)
#         The possibility to select a local location (i.e. based on Windows path)
#
#     Output
#     ----
#     currencies_df (pd.DataFrame)
#         Returns a dictionary with a selection or all data based on the input.

# %% [markdown]
# With this information in hand, and having seen the available options within [Understanding the available options](#understanding-the-available-options), we can specify the selection as follows:

# %%
currencies.select(currency='USD')
# Out:
#          short_name currency exchange      market
# symbol
# AEDUSD=X    AED/USD      USD      CCY  ccy_market
# AFNUSD=X    AFN/USD      USD      CCY  ccy_market
# ALLUSD=X    ALL/USD      USD      CCY  ccy_market
# ANGUSD=X    ANG/USD      USD      CCY  ccy_market
# AOAUSD=X    AOA/USD      USD      CCY  ccy_market
# ...             ...      ...      ...         ...
# XCUUSD=X    XCU/USD      USD      CCY  ccy_market
# XDRUSD=X    XDR/USD      USD      CCY  ccy_market
# XOFUSD=X    XOF/USD      USD      CCY  ccy_market
# ZARUSD=X    ZAR/USD      USD      CCY  ccy_market
# ZMWUSD=X    ZMW/USD      USD      CCY  ccy_market
#
# [135 rows x 4 columns]

# %% [markdown]
# ## Cryptocurrencies

# %% [markdown]
# If you wish to collect data from all cryptocurrencies you can use the following:

# %%
cryptos = fd.Cryptos()

cryptos.select()
# Out:
#             short_name cryptocurrency currency  \
# symbol
# AAVE-CAD      Aave CAD           AAVE      CAD
# AAVE-CNY      Aave CNY           AAVE      CNY
# AAVE-ETH      Aave ETH           AAVE      ETH
# AAVE-EUR      Aave EUR           AAVE      EUR
# AAVE-GBP      Aave GBP           AAVE      GBP
# ...                ...            ...      ...
# ZYN-INR   Zynecoin INR            ZYN      INR
# ZYN-JPY   Zynecoin JPY            ZYN      JPY
# ZYN-KRW   Zynecoin KRW            ZYN      KRW
# ZYN-RUB   Zynecoin RUB            ZYN      RUB
# ZYN-USD   Zynecoin USD            ZYN      USD
#
#                                                     summary exchange  \
# symbol
# AAVE-CAD  Aave (AAVE) is a cryptocurrency and operates o...      CCC
# AAVE-CNY  Aave (AAVE) is a cryptocurrency and operates o...      CCC
# AAVE-ETH  Aave (AAVE) is a cryptocurrency and operates o...      CCC
# AAVE-EUR  Aave (AAVE) is a cryptocurrency and operates o...      CCC
# AAVE-GBP  Aave (AAVE) is a cryptocurrency and operates o...      CCC
# ...                                                     ...      ...
# ZYN-INR   Zynecoin (ZYN) is a cryptocurrency . Users are...      CCC
# ZYN-JPY   Zynecoin (ZYN) is a cryptocurrency . Users are...      CCC
# ZYN-KRW   Zynecoin (ZYN) is a cryptocurrency . Users are...      CCC
# ZYN-RUB   Zynecoin (ZYN) is a cryptocurrency . Users are...      CCC
# ZYN-USD   Zynecoin (ZYN) is a cryptocurrency . Users are...      CCC
#
#               market
# symbol
# AAVE-CAD  ccc_market
# AAVE-CNY  ccc_market
# AAVE-ETH  ccc_market
# AAVE-EUR  ccc_market
# AAVE-GBP  ccc_market
# ...              ...
# ZYN-INR   ccc_market
# ZYN-JPY   ccc_market
# ZYN-KRW   ccc_market
# ZYN-RUB   ccc_market
# ZYN-USD   ccc_market
#
# [3367 rows x 6 columns]

# %% [markdown]
# This returns approximately 3.000 different cryptocurrencies. Find a more elaborate explanation with `help(cryptos.select)`:

# %%
help(cryptos.select)
# Out:
# Help on method select in module financedatabase.cryptos:
#
# select(crypto: str = '', capitalize: bool = True) -> pandas.core.frame.DataFrame method of financedatabase.cryptos.Cryptos instance
#     Description
#     ----
#     Returns all cryptos when no input is given and has the option to give
#     a specific combination of cryptos based on the crypto defined.
#
#
#     Input
#     ----
#     crypto (string, default is None)
#         If filled, gives all data for a specific crypto.
#     capitalize (boolean, default is True):
#         Whether the crypto needs to be capitalized. By default the values
#         always are capitalized as that is also how it is represented in the csv files.
#     base_url (string, default is GitHub location)
#         The possibility to enter your own location if desired.
#     use_local_location (string, default False)
#         The possibility to select a local location (i.e. based on Windows path)
#
#     Output
#     ----
#     cryptos_df (pd.DataFrame)
#         Returns a dictionary with a selection or all data based on the input.

# %% [markdown]
# With this information in hand, and having seen the available options within [Understanding the available options](#understanding-the-available-options), we can specify the selection as follows. Which returns a total of 5 combination of cryptocurrencies that include the ETH.

# %%
cryptos.select(crypto='ETH')
# Out:
#            short_name cryptocurrency currency  \
# symbol
# ETH-BTC  Ethereum BTC            ETH      BTC
# ETH-CAD  Ethereum CAD            ETH      CAD
# ETH-EUR  Ethereum EUR            ETH      EUR
# ETH-GBP  Ethereum GBP            ETH      GBP
# ETH-USD  Ethereum USD            ETH      USD
#
#                                                    summary exchange  \
# symbol
# ETH-BTC  Ethereum (ETH) is a cryptocurrency . Users are...      CCC
# ETH-CAD  Ethereum (ETH) is a cryptocurrency . Users are...      CCC
# ETH-EUR  Ethereum (ETH) is a cryptocurrency . Users are...      CCC
# ETH-GBP  Ethereum (ETH) is a cryptocurrency . Users are...      CCC
# ETH-USD  Ethereum (ETH) is a cryptocurrency . Users are...      CCC
#
#              market
# symbol
# ETH-BTC  ccc_market
# ETH-CAD  ccc_market
# ETH-EUR  ccc_market
# ETH-GBP  ccc_market
# ETH-USD  ccc_market

# %% [markdown]
# ## Moneymarkets

# %% [markdown]
# If you wish to collect data from all money markets you can use the following:

# %%
moneymarkets = fd.Moneymarkets()

moneymarkets.select()
# Out:
#                             short_name  \
# AABXX                              NaN
# AAFXX  American Funds U.S. Government
# AALXX  Thrivent Money Market Fund Clas
# AAOXX  American Beacon U.S. Government
# AARXX                              NaN
# ...                                ...
# WRNXX  Ivy Government Money Market Cla
# WTLXX  Wells Fargo Treasury Plus Money
# WTPXX  Wells Fargo Fd, Treasury Plus M
# WTRXX  Wells Fargo 100% Treasurey Mone
# WUCXX  Wells Fargo Municipal Cash Mgmt
#
#                                                long_name currency     market  \
# AABXX                                                NaN      USD  us_market
# AAFXX                                                NaN      USD  us_market
# AALXX  Thrivent Mutual Funds - Thrivent Money Market ...      USD  us_market
# AAOXX  American Beacon U.S. Government Money Market S...      USD  us_market
# AARXX                                                NaN      USD  us_market
# ...                                                  ...      ...        ...
# WRNXX       Ivy Funds - Ivy Government Money Market Fund      USD  us_market
# WTLXX  Wells Fargo Funds Trust - Treasury Plus Money ...      USD  us_market
# WTPXX  Wells Fargo Funds Trust - Treasury Plus Money ...      USD  us_market
# WTRXX  Wells Fargo Funds Trust - 100% Treasury Money ...      USD  us_market
# WUCXX  Wells Fargo Advantage Money Market Funds - Mun...      USD  us_market
#
#       exchange
# AABXX      NAS
# AAFXX      NAS
# AALXX      NAS
# AAOXX      NAS
# AARXX      NAS
# ...        ...
# WRNXX      NAS
# WTLXX      NAS
# WTPXX      NAS
# WTRXX      NAS
# WUCXX      NAS
#
# [1364 rows x 5 columns]

# %% [markdown]
# This returns approximately 3.000 different money markets. Find a more elaborate explanation with `help(fd.select_moneymarkets)`:

# %%
help(moneymarkets.select)
# Out:
# Help on method select in module financedatabase.moneymarkets:
#
# select(currency: str = '', capitalize: bool = True, exclude_exchanges: bool = True) -> pandas.core.frame.DataFrame method of financedatabase.moneymarkets.Moneymarkets instance
#     Description
#     ----
#     Returns all moneymarkets when no input is given and has the option to give
#     a specific combination of moneymarkets based on the currency defined.
#
#     Input
#     ----
#     currency (string, default is None)
#         If filled, gives all data for a specific currency.
#     capitalize (boolean, default is True):
#         Whether the currency needs to be capitalized. By default the values
#         always are capitalized as that is also how it is represented in the csv files.
#     exclude_exchanges (boolean, default is True):
#         Whether you want to exclude exchanges from the search. If False,
#         you will receive multiple times the product from different exchanges.
#     base_url (string, default is GitHub location)
#         The possibility to enter your own location if desired.
#     use_local_location (string, default False)
#         The possibility to select a local location (i.e. based on Windows path)
#
#     Output
#     ----
#     indices_df (pd.DataFrame)
#         Returns a dictionary with a selection or all data based on the input.

# %% [markdown]
# # Searching the database in detail

# %% [markdown]
# All asset classes have the capability to search each column with `search`, for example `equities.search()`. Through how this functionality is developed you can define multiple columns and search throughoutly. For example:

# %%
# Collect all Equities Database
equities = fd.Equities()

# Search Multiple Columns
equities.search(summary='automotive', currency='EUR', country='Germany')
# Out:
#                            short_name  \
# symbol
# 0E4J.L   DELTICOM AG DELTICOM ORD SHS
# 0G73.L     SOFTING AG SOFTING ORD SHS
# 0J9O.L           MANZ AG MANZ ORD SHS
# 0N5I.L     ADESSO AG ADESSO K ORD SHS
# 0NFG.L     PARAGON AG PARAGON ORD SHS
# ...                               ...
# YSN.DE       SECUNET SECURITY AG O.N.
# YSN.F        SECUNET SECURITY AG O.N.
# ZIL2.DE      ELRINGKLINGER AG NA O.N.
# ZIL2.F       ELRINGKLINGER AG NA O.N.
# ZIL2.VI              ELRINGKLINGER AG
#
#                                             long_name  \
# symbol
# 0E4J.L                                    Delticom AG
# 0G73.L                                     Softing AG
# 0J9O.L                                        Manz AG
# 0N5I.L                                      adesso SE
# 0NFG.L                        paragon GmbH & Co. KGaA
# ...                                               ...
# YSN.DE   secunet Security Networks Aktiengesellschaft
# YSN.F    secunet Security Networks Aktiengesellschaft
# ZIL2.DE                              ElringKlinger AG
# ZIL2.F                               ElringKlinger AG
# ZIL2.VI                              ElringKlinger AG
#
#                                                    summary currency  \
# symbol
# 0E4J.L   Delticom AG, together with its subsidiaries, o...      EUR
# 0G73.L   Softing AG develops software, hardware, and sy...      EUR
# 0J9O.L   Manz AG engages in the manufacture and sale of...      EUR
# 0N5I.L   adesso SE operates as an IT service provider f...      EUR
# 0NFG.L   paragon GmbH & Co. KGaA develops, manufactures...      EUR
# ...                                                    ...      ...
# YSN.DE   secunet Security Networks Aktiengesellschaft o...      EUR
# YSN.F    secunet Security Networks Aktiengesellschaft o...      EUR
# ZIL2.DE  ElringKlinger AG develops, manufactures, and d...      EUR
# ZIL2.F   ElringKlinger AG develops, manufactures, and d...      EUR
# ZIL2.VI  ElringKlinger AG develops, manufactures, and d...      EUR
#
#                     sector                         industry exchange  \
# symbol
# 0E4J.L                 NaN                              NaN      LSE
# 0G73.L                 NaN                              NaN      LSE
# 0J9O.L                 NaN                              NaN      LSE
# 0N5I.L                 NaN                              NaN      LSE
# 0NFG.L                 NaN                              NaN      LSE
# ...                    ...                              ...      ...
# YSN.DE          Technology  Information Technology Services      GER
# YSN.F           Technology  Information Technology Services      FRA
# ZIL2.DE  Consumer Cyclical                       Auto Parts      GER
# ZIL2.F   Consumer Cyclical                       Auto Parts      FRA
# ZIL2.VI  Consumer Cyclical                       Auto Parts      VIE
#
#             market  country state                   city zipcode  \
# symbol
# 0E4J.L   gb_market  Germany   NaN                Hanover   30169
# 0G73.L   gb_market  Germany   NaN                   Haar   85540
# 0J9O.L   gb_market  Germany   NaN             Reutlingen   72768
# 0N5I.L   gb_market  Germany   NaN               Dortmund   44269
# 0NFG.L   gb_market  Germany   NaN              DelbrÃ¼ck   33129
# ...            ...      ...   ...                    ...     ...
# YSN.DE   de_market  Germany   NaN                  Essen   45138
# YSN.F    dr_market  Germany   NaN                  Essen   45138
# ZIL2.DE  de_market  Germany   NaN  Dettingen an der Erms   72581
# ZIL2.F   dr_market  Germany   NaN  Dettingen an der Erms   72581
# ZIL2.VI  at_market  Germany   NaN  Dettingen an der Erms   72581
#
#                                website market_cap
# symbol
# 0E4J.L            http://www.delti.com  Micro Cap
# 0G73.L   http://company.softing.com/de  Micro Cap
# 0J9O.L             http://www.manz.com  Small Cap
# 0N5I.L            http://www.adesso.de  Small Cap
# 0NFG.L           http://www.paragon.ag   Nano Cap
# ...                                ...        ...
# YSN.DE          http://www.secunet.com    Mid Cap
# YSN.F           http://www.secunet.com    Mid Cap
# ZIL2.DE   http://www.elringklinger.com  Small Cap
# ZIL2.F    http://www.elringklinger.com  Small Cap
# ZIL2.VI   http://www.elringklinger.com  Small Cap
#
# [221 rows x 14 columns]

# %%
# Collect all Moneymarket Database
moneymarkets = fd.Moneymarkets()

# Search Multiple Columns
moneymarkets.search(long_name='treasury fund', market='us_market')
# Out:
#                             short_name  \
# APGXX  Cavanal Hill U.S. Treasury Fund
# APJXX  Cavanal Hill U.S. Treasury Fund
# APKXX  Cavanal Hill U.S. Treasury Fund
# APNXX  Cavanal Hill U.S. Treasury Sele
# FDCXX  Fidelity Treasury Money Market
# FDUXX  Fidelity Treasury Money Market
# FSRXX  Fidelity Treasury Money Market
# FZFXX  Fidelity Treasury Money Market
# PRTXX  T. Rowe Price U.S. Treasury Mon
# TRGXX  U.S. Treasury Money Fund - I Cl
# TRIXX  State Street Insti Treasury Fd
# TRVXX  State Street Institutional Trea
# TRZXX  T. Rowe Price U.S. Treasury Mon
#
#                                                long_name currency     market  \
# APGXX            Cavanal Hill Funds - U.S. Treasury Fund      USD  us_market
# APJXX            Cavanal Hill Funds - U.S. Treasury Fund      USD  us_market
# APKXX            Cavanal Hill Funds - U.S. Treasury Fund      USD  us_market
# APNXX            Cavanal Hill Funds - U.S. Treasury Fund      USD  us_market
# FDCXX      Fidelity Newbury Street Trust - Treasury Fund      USD  us_market
# FDUXX      Fidelity Newbury Street Trust - Treasury Fund      USD  us_market
# FSRXX      Fidelity Newbury Street Trust - Treasury Fund      USD  us_market
# FZFXX      Fidelity Newbury Street Trust - Treasury Fund      USD  us_market
# PRTXX  T. Rowe Price U.S. Treasury Funds, Inc. - T. R...      USD  us_market
# TRGXX  T. Rowe Price U.S. Treasury Funds, Inc. - T. R...      USD  us_market
# TRIXX  State Street Institutional Investment Trust - ...      USD  us_market
# TRVXX  State Street Institutional Investment Trust - ...      USD  us_market
# TRZXX  T. Rowe Price U.S. Treasury Funds, Inc. - T. R...      USD  us_market
#
#       exchange
# APGXX      NAS
# APJXX      NAS
# APKXX      NAS
# APNXX      NAS
# FDCXX      NAS
# FDUXX      NAS
# FSRXX      NAS
# FZFXX      NAS
# PRTXX      NAS
# TRGXX      NAS
# TRIXX      NAS
# TRVXX      NAS
# TRZXX      NAS
